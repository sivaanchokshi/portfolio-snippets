# %%
from random import choices, randint, randrange, random, sample
num_to_colour={0:"Red",1:"Orange",2:"Yellow",3:"Green",4:"Black",5:"Purple",6:"Blue",7:"White"}
colour_to_num={"Red":0,"Orange":1,"Yellow":2,"Green":3,"Black":4,"Purple":5,"Blue":6,"White":7}

issue=[]
correct=[0,0,0,0,0,0,0,0]
solution=[]

def generate_new_issue():
    for i in range (4):
        issue.append(num_to_colour[randint(0,7)])
    print(issue)

def finding_colours():
    #for i in range(2):
        for j in range (4):
            solution.append(num_to_colour[j])
        print(solution)
    #check if colour is there at all
        for x in range(4):
            for j in range(4):
                if solution[x]==issue[j]:
                     correct[x]=1
                     #checking if its in the correct place
                     if x==j:
                          correct[x]=2
        print(correct)
        #second set of colours
        for j in range (4):
             solution[j]=num_to_colour[4+j]
        print(solution)
        for x in range(4):
            for j in range(4):
                if solution[x]==issue[j]:
                     correct[4+x]=1
                     #checking if its in the correct place
                     if x==j:
                          correct[4+x]=2
        print(correct)

def ncal(var):
     total=0
     for i in range(len(var)):
         if var[i]!=0:
              total+=1
     return total


def fill_with_correct_colours():
     index=0
     for i in range (4):
        if correct[i]==1:
              solution[i]=num_to_colour[i]
              index+=1
        if correct[i]==2:
             solution[i]==num_to_colour[i]
     print(index)
     for i in range(4):
        if correct[i+4]==1:
              solution[i+index]=num_to_colour[i+4]
        if correct[i+4]==2:
             solution[i]=num_to_colour[i]
     print(solution)
              
              

              


        





generate_new_issue()
finding_colours()
print(ncal(correct))
fill_with_correct_colours()
# Out:
# ['Black', 'Red', 'Red', 'Orange']
# ['Red', 'Orange', 'Yellow', 'Green']
# [1, 1, 0, 0, 0, 0, 0, 0]
# ['Black', 'Purple', 'Blue', 'White']
# [1, 1, 0, 0, 2, 0, 0, 0]
# 3
# 2
# ['Red', 'Orange', 'Blue', 'White']
